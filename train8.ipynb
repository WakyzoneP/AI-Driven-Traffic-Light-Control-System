# %%
from agent import Agent

agent = Agent("./config/config2.json", hidden_layers=2, activation_function="relu")
results = agent.train(number_of_epos=40, exploration_games_ratio=0.6, save_results=True, save_type="json")
# Out:
# Exploration games: 60.0
# Environment created
# Inhance:  2
# Max Shape:  2
# Health:  1500
# Intersections:  3
# Traffic Level:  1
# Car Spawn Rate:  20
# Step Time:  350
# Car Speed:  2
# Epo 1: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 13.64
# Record: 25
# Epo mean score: 13.64
# Epo record: 25
# Epo 2: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 13.16
# Record: 27
# Epo mean score: 12.68
# Epo record: 27
# Epo 3: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 12.596666666666666
# Record: 32
# Epo mean score: 11.47
# Epo record: 32
# Epo 4: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 12.06
# Record: 32
# Epo mean score: 10.45
# Epo record: 27
# Epo 5: |████████------------------------------------------| 17.0% Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from agent import Agent
#       3 agent = Agent("./config/config2.json", hidden_layers=2, activation_function="relu")
# ----> 4 results = agent.train(number_of_epos=40, exploration_games_ratio=0.6, save_results=True, save_type="json")
#
# File ~/User Documents/Licenta/agent.py:216, in Agent.train(self, number_of_epos, show_ui, show_plot, exploration_games_ratio, save_results, save_type)
#     214 env.reset()
#     215 self.n_games += 1
# --> 216 self.train_long_memory()
#     218 if score > record:
#     219     record = score
#
# File ~/User Documents/Licenta/agent.py:133, in Agent.train_long_memory(self)
#     130     mini_sample = self.memory
#     132 states, actions, rewards, next_states, dones = zip(*mini_sample)
# --> 133 self.trainer.train_step(states, actions, rewards, next_states, dones)
#
# File ~/User Documents/Licenta/model.py:124, in QTrainer.train_step(self, state, action, reward, next_state, done)
#     122 self.optimizer.zero_grad()
#     123 loss = self.criterion(target, pred)
# --> 124 loss.backward()
#     126 self.optimizer.step()
#
# File ~/User Documents/Licenta/.venv/lib/python3.9/site-packages/torch/_tensor.py:523, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     513 if has_torch_function_unary(self):
#     514     return handle_torch_function(
#     515         Tensor.backward,
#     516         (self,),
#    (...)
#     521         inputs=inputs,
#     522     )
# --> 523 torch.autograd.backward(
#     524     self, gradient, retain_graph, create_graph, inputs=inputs
#     525 )
#
# File ~/User Documents/Licenta/.venv/lib/python3.9/site-packages/torch/autograd/__init__.py:284, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     279     retain_graph = create_graph
#     281 # The reason we repeat the same comment below is that
#     282 # some Python versions print out the first line of a multi-line function
#     283 # calls in the traceback and some print out the last line
# --> 284 _engine_run_backward(
#     285     tensors,
#     286     grad_tensors_,
#     287     retain_graph,
#     288     create_graph,
#     289     inputs,
#     290     allow_unreachable=True,
#     291     accumulate_grad=True,
#     292 )
#
# File ~/User Documents/Licenta/.venv/lib/python3.9/site-packages/torch/autograd/graph.py:767, in _engine_run_backward(t_outputs, *args, **kwargs)
#     765     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     766 try:
# --> 767     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     768         t_outputs, *args, **kwargs
#     769     )  # Calls into the C++ engine to run the backward pass
#     770 finally:
#     771     if attach_logging_hooks:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from helper import plot

plot(results.score.scores, results.score.mean_scores)

# %%
from helper import means_plot

means_plot(results.score.mean_scores)
