# %%
from agent import train

plot_scores, plot_mean_scores = train(number_of_epos=100, show_ui=False, show_plot=False, exploration_games_ratio=0.1)
# Out:
# Epo 1: |██████████████████████████████████████████████████| 100.0% Complete
# Game 100: 3
# Mean: 8.3
# Record: 17
# Epo 2: |██████████████████████████████████████████████████| 100.0% Complete
# Game 200: 8
# Mean: 8.02
# Record: 17
# Epo 3: |██████████████████████████████████████████████████| 100.0% Complete
# Game 300: 8
# Mean: 8.003333333333334
# Record: 18
# Epo 4: |██████████████████████████████████████████████████| 100.0% Complete
# Game 400: 12
# Mean: 7.9575
# Record: 18
# Epo 5: |██████████████████████████████████████████████████| 100.0% Complete
# Game 500: 7
# Mean: 7.84
# Record: 18
# Epo 6: |██████████████████████████████████████████████████| 100.0% Complete
# Game 600: 12
# Mean: 7.801666666666667
# Record: 18
# Epo 7: |██████████████████████████████████████████████████| 100.0% Complete
# Game 700: 9
# Mean: 7.807142857142857
# Record: 18
# Epo 8: |██████████████████████████████████████████████████| 100.0% Complete
# Game 800: 7
# Mean: 7.825
# Record: 18
# ...

# %%
from helper import plot

plot(plot_scores, plot_mean_scores)

# %%
plot_scores, plot_mean_scores = train(number_of_epos=100, show_ui=False, show_plot=False, exploration_games_ratio=0.1)
# Out:
# Epo 1: |██████████████████████████████████████████████████| 100.0% Complete
# Game 100: 7
# Mean: 8.45
# Record: 17
# Epo 2: |██████████████████████████████████████████████████| 100.0% Complete
# Game 200: 10
# Mean: 8.475
# Record: 19
# Epo 3: |██████████████████████████████████████████████████| 100.0% Complete
# Game 300: 6
# Mean: 8.62
# Record: 23
# Epo 4: |██████████████████████████████████████████████████| 100.0% Complete
# Game 400: 4
# Mean: 8.685
# Record: 25
# Epo 5: |██████████████████████████████████████████████████| 100.0% Complete
# Game 500: 4
# Mean: 8.644
# Record: 25
# Epo 6: |██████████████████████████████████████████████████| 100.0% Complete
# Game 600: 9
# Mean: 8.653333333333334
# Record: 25
# Epo 7: |██████████████████████████████████████████████████| 100.0% Complete
# Game 700: 5
# Mean: 8.635714285714286
# Record: 25
# Epo 8: |██████████████████████████████████████████████████| 100.0% Complete
# Game 800: 5
# Mean: 8.6
# Record: 25
# ...

# %%
plot(plot_scores, plot_mean_scores)

# %%
import torch
from agent import train

result = train(number_of_epos=100, show_ui=False, show_plot=False, exploration_games_ratio=0.1)
# Out:
# Epo 1: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.5
# Record: 16
# Epo mean score: 6.5
# Epo record: 16
# Epo 2: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.645
# Record: 16
# Epo mean score: 6.79
# Epo record: 15
# Epo 3: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.55
# Record: 16
# Epo mean score: 6.36
# Epo record: 15
# Epo 4: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.5025
# Record: 16
# Epo mean score: 6.36
# Epo record: 14
# Epo 5: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.502
# Record: 18
# Epo mean score: 6.5
# Epo record: 18
# Epo 6: |██████████████████████████████████████████████████| 100.0% Complete
# Mean score: 6.566666666666666
# Record: 18
# Epo mean score: 6.89
# Epo record: 16
# Epo 7: |██████████████████████████████████████████████████| 100.0% Complete
# ...

# %%
from helper import plot

plot(result.score.scores, result.score.mean_scores)

# %%
import numpy as np

np.argmax(result.score.scores), np.max(result.score.scores)
# Out:
# (4416, 24)

# %%
np.argmax(result.epos.epo_means), np.max(result.epos.epo_means)
# Out:
# (14, 7.99)

# %%
from agent import Agent

agent = Agent()
agent.simulate()
