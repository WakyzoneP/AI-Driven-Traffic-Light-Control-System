# %%
from agent import Agent

agent = Agent("./config/config1.json")
results = agent.train(10, show_ui=False, show_plot=False, exploration_games_ratio=0.1)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 3
# [<environment.objects.intersection.Intersection object at 0x1456dd910>, <environment.objects.intersection.Intersection object at 0x107fab0d0>, <environment.objects.intersection.Intersection object at 0x135153f70>]
# 2024-06-08 21:24:17.232 Python[796:2231985] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# /Users/vladberaru/User Documents/Licenta/model.py:55: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
# ...

# %%
from helper import plot

plot(results.score.scores, results.score.mean_scores)

# %%
agent.simulate()
# Out:
# 3
# [<environment.objects.intersection.Intersection object at 0x33c1e7e50>, <environment.objects.intersection.Intersection object at 0x107f55460>, <environment.objects.intersection.Intersection object at 0x107f55850>]
# Loading model from model-config1.pth
# Move: 15
# Move: 15
# Move: 59
# Move: 60
# Move: 42
# Move: 59
# Move: 21
# Move: 21
# Move: 60
# Move: 2
# Move: 28
# Move: 2
# Move: 21
# Move: 60
# Move: 2
# Move: 31
# Move: 2
# Move: 21
# Move: 59
# Move: 21
# Move: 60
# Move: 51
# Move: 28
# Move: 35
# Move: 45
# Move: 60
# Move: 59
# Move: 2
# Move: 21
# Move: 35
# Move: 15
# Move: 59
# Move: 35
# Move: 21
# Move: 59
# Move: 21
# Move: 28
# Move: 2
# Move: 59
# Move: 21
# Move: 2
# Move: 60
# Move: 35
# Move: 21
# Move: 59
# Move: 2
# Move: 60
# Move: 2
# Move: 28
# Move: 2
# Move: 21
# Move: 59
# Move: 4
# Move: 21
# Move: 59
# Move: 2
# Move: 21
# Move: 60
# Move: 2
# Move: 21
# Move: 60
# Move: 35
# ...

# %%
from agent import Agent

agent = Agent("./config/config2.json")
results = agent.train(10, show_ui=False, show_plot=False, exploration_games_ratio=0.2)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 5
# [<environment.objects.intersection.Intersection object at 0x10493b1c0>, <environment.objects.intersection.Intersection object at 0x11f3d8490>, <environment.objects.intersection.Intersection object at 0x11f3d8520>]
# 2024-06-08 20:41:50.906 Python[97459:2171361] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# /Users/vladberaru/User Documents/Licenta/model.py:55: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
# ...

# %%
from helper import plot

plot(results.score.scores, results.score.mean_scores)
