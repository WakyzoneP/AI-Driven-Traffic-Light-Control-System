# %%
from agent import Agent

agent = Agent("./config/config2.json", hidden_layers=2, activation_function="relu")
results = agent.train(number_of_epos=30, exploration_games_ratio=0.5, save_results=True, save_type="binary")
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Exploration games: 50.0
# Environment created
# Inhance:  2
# Max Shape:  2
# Health:  1500
# Intersections:  3
# Traffic Level:  1
# Car Spawn Rate:  20
# Step Time:  200
# Car Speed:  2
# 2024-06-13 22:39:06.842 Python[72698:8710879] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
# /Users/vladberaru/User Documents/Licenta/model.py:94: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
# ...

# %%
from helper import plot

plot(results.score.scores, results.score.mean_scores)

# %%
from helper import means_plot

means_plot(results.score.mean_scores)
